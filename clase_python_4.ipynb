# %% [markdown]
# ## Temario
# - Funciones
# - Funciones Lambda
# - Errores (Excepciones)

# %% [markdown]
# ## Funciones
#  Estas son un bloque de codigo reutilizable que podemos mandar a llamar varias veces en el codigo

# %%
def mensaje():
  print("Hola Mundo")

mensaje()
# Out:
# Hola Mundo

# %%
# Funcion con retorno
def mensaje():
  return "Hola"
print(mensaje())
va = mensaje()
print(va)
# Out:
# Hola
# Hola

# %%
def saludo(nombre):
  print("Hola", nombre,)

tuNombre = input("Ingresa tu Nombre: ")
saludo(tuNombre)
#Nota: El nombre de la variable del parametro puede o no ser el mismo fuera de la funcion
# Out:
# Ingresa tu Nombre: Pedro
# Hola Pedro

# %%
# Se puede mandarle el parametro de esta manera
saludo("Grupo")
# Out:
# Hola Grupo

# %%
def suma(numero_1, numero_2):
  return numero_1 + numero_2
print(suma(12,11))
# Out:
# 23

# %%
def bienvenida(nombre = "cliente"):
  print("Hola", nombre)
bienvenida()
bienvenida("Pedro")
# Out:
# Hola cliente
# Hola Pedro

# %%
def suma(numero_1 = 2, numero_2 = 10): # Se puede poner tantos parametros como queramos
  return numero_1 + numero_2
suma = suma(232,142)
print(suma)
# Out:
# 374

# %%
# Descuento
def descuento(precio, desc = 0.15):
  precio = precio * (1 - desc)
  print("El nuevo precio es: ",precio)
descuento(600)
descuento(600,.25)
# Out:
# El nuevo precio es:  510.0
# El nuevo precio es:  450.0

# %%
def usuario(nombre,edad):
  return nombre,edad
persona = usuario("PEdro",21)
print(type(persona))
print(persona)
# Out:
# <class 'tuple'>
# ('PEdro', 21)

# %%
def operaciones(numero):
  doble = numero * 2
  triple = numero * 3
  cuadruple = numero * 4
  quintuple = numero * 5
  return doble, triple, cuadruple, quintuple
resultado = operaciones(1)
print(resultado)
# Out:
# (2, 3, 4, 5)

# %% [markdown]
# ## Funciones que llaman a otras funciones

# %%
def saludar(nombre):
  return f"Hola, {nombre}"

def despedirse(nombre):
  return f"Adios, {nombre}"

def mensaje_completo(nombre):
  saludo = saludar(nombre)
  despedida = despedirse(nombre)
  return saludo + "\n" + despedida   # \n es un alto de linea

print(mensaje_completo("Pedro"))
# Out:
# Hola, Pedro
# Adios, Pedro

# %%
# Ahora supongamos que tenemos una heladeria
def pedir_sabor():
  sabores = ["vainilla", "chocolate","fresa"]
  print("Sabor disponible", ",", sabores)
  # lower() hace minusculas las palabras
  # strip() elimina los espacios tanto antes como despues
  sabor = input("Elige un sabor: ").strip().lower()
  # si sabor NO esta en sabores
  while sabor not in sabores:
    sabor = input("Elige un sabor (nuevamente): ").strip().lower()
  return sabor

def pedir_cantidad():
  cantidad = int(input("Cuantas bolas de nieve?: "))
  while cantidad <= 0:
    cantidad = int(input("Cuantas bolas de nieve? (ingresa un valor valido): "))
  return cantidad
# Funcion Madre (llama a otras funciones)
def pedir_helado():
  sabor = pedir_sabor()
  cant = pedir_cantidad()
  print(f"Pedido: {cant} bola(s) de {sabor}")
  return cant, sabor

total_pedidos = int(input("Cuantos clientes atenderas? : "))
for i in range(total_pedidos):
  pedir_helado()
# Out:
# Cuantos clientes atenderas? : 2
# Sabor disponible , ['vainilla', 'chocolate', 'fresa']
# Elige un sabor: platano
# Elige un sabor (nuevamente): chocolate
# Cuantas bolas de nieve?: 3
# Pedido: 3 bola(s) de chocolate
# Sabor disponible , ['vainilla', 'chocolate', 'fresa']
# Elige un sabor: vainilla
# Cuantas bolas de nieve?: 1
# Pedido: 1 bola(s) de vainilla

# %% [markdown]
# ## Funciones Lambda
# Una funcion lambda es una funcion acortada para escribir una funcion de esta forma:
#
# nombreFuncion = lambda parametros: accion
#
# La diferencia entre las funciones lambda y las funciones normales es que suelen ser mas limitadas

# %%
sumar = lambda x,y : x+y
print(sumar(5,10))
# Out:
# 15

# %%
descuentoLambda = lambda desc, precio: ((precio * (1-desc)),(precio * desc))
nuevoPrecio = descuentoLambda(0.16,400)
print("El precio a pagar es", nuevoPrecio[0], ", el descuento que se hizo fue de: ", nuevoPrecio[1])
print(type(nuevoPrecio))
# Out:
# El precio a pagar es 336.0 , el descuento que se hizo fue de:  64.0
# <class 'tuple'>

# %% [markdown]
# ## Errores (excepciones)

# %%
print(10/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-179726827.py in <cell line: 0>()
# ----> 1 print(10/0)
#
# ZeroDivisionError: division by zero

# %%
try:
  dividendo = float(input("Ingresa el dividendo: "))
  divisor = float(input("Ingresa el divisor: "))
  division = dividendo / divisor
except ZeroDivisionError:
  print("Error: el divisor no puede  ser 0")
# Out:
# Ingresa el dividendo: 4
# Ingresa el divisor: 0
# Error: el divisor no puede  ser 0

# %%
#Hay otros tipos de errores, por ejemplo, el de ValueError que sale al ingresar el tipo incorrecto de dato#Digamos que un usuario ingresa texto en un lugar de un número, esto nos ayuda a manejarlo
try:
  numero = int(input("Escriba un numero: "))
  print(numero)
except ValueError:
  print("Ingrese un valor numerico")
# Out:
# Escriba un numero: a
# Ingrese un valor numerico

# %%
def promediosYmayor(promedios):
    promedio = 0
    for x in promedios:
        promedio += x
    promedio = promedio / len(promedios)
    return promedio, max(promedios)


promedios = []
continuar = ""

while True:
    if len(promedios) > 0:
        continuar = ""
        while continuar not in ("si", "no"):
            continuar = input("¿Desea ingresar otra calificación? (si/no): ").lower()
        if continuar == "no":
            break

    while True:
        try:
            calif = int(input("Indique la calificación: "))
            if calif < 0 or calif > 100:
                print("Ingrese un valor válido (0 a 100)")
            else:
                promedios.append(calif)
                break
        except ValueError:
            print("Ingrese un valor numérico")

prom, mayor = promediosYmayor(promedios)

print("\nResultados:")
print("Promedio:", prom)
print("Mayor:", mayor)
# Out:
# Indique la calificación: 70
# ¿Desea ingresar otra calificación? (si/no): i
# ¿Desea ingresar otra calificación? (si/no): si
# Indique la calificación: 89
# ¿Desea ingresar otra calificación? (si/no): n
# ¿Desea ingresar otra calificación? (si/no): no
#
# Resultados:
# Promedio: 79.5
# Mayor: 89

# %%
# Tambien podemos manejar mas de una excepcion, por ejemplo, con la dicision
#podemos tener tanto el tipo de valor como el de la division entre 0
try:
  dividendo = float(input("Ingresa el dividendo: "))
  divisor = float(input("Ingresa el divisor: "))
  division = dividendo / divisor
except ZeroDivisionError:
  print("Error: el divisor no debe de ser 0")
except ValueError:
  print("Error: Ingrese un valor numerico")
# Out:
# Ingresa el dividendo: 2
# Ingresa el divisor: a
# Error: Ingrese un valor numerico

# %%
# Calculadora -> suma, resta, producto, division y potencia
def suma(a, b):
    return a + b

def resta(a, b):
    return a - b

def producto(a, b):
    return a * b

def division(a, b):
    if b == 0:
        return "Error: no se puede dividir entre 0"
    return a / b

def potencia(a, b):
    return a ** b

def menu():
    print("-------- MI CALCULADORA --------")
    print("1. Suma")
    print("2. Resta")
    print("3. Producto")
    print("4. División")
    print("5. Potencia")
    print("6. Salir")

while True:
    menu()
    try:
        op = int(input("Seleccione una opción: "))
    except ValueError:
        print("Ingrese un número válido")
        continue

    if op == 6:
        print("SALIENDO...")
        break

    if op < 1 or op > 6:
        print("Opción inválida")
        continue

    try:
        a = float(input("Ingrese el primer número: "))
        b = float(input("Ingrese el segundo número: "))
    except ValueError:
        print("Error: Ingrese un número válido")
        continue

    if op == 1:
        print("Resultado:", suma(a, b))
    elif op == 2:
        print("Resultado:", resta(a, b))
    elif op == 3:
        print("Resultado:", producto(a, b))
    elif op == 4:
        print("Resultado:", division(a, b))
    elif op == 5:
        print("Resultado:", potencia(a, b))
# Out:
# -------- MI CALCULADORA --------
# 1. Suma
# 2. Resta
# 3. Producto
# 4. División
# 5. Potencia
# 6. Salir
# Seleccione una opción: 1
# Ingrese el primer número: 2
# Ingrese el segundo número: 4
# Resultado: 6.0
# -------- MI CALCULADORA --------
# 1. Suma
# 2. Resta
# 3. Producto
# 4. División
# 5. Potencia
# 6. Salir
# Seleccione una opción: 8
# Opción inválida
# -------- MI CALCULADORA --------
# 1. Suma
# 2. Resta
# 3. Producto
# 4. División
# 5. Potencia
# 6. Salir
# Seleccione una opción: a
# Ingrese un número válido
# -------- MI CALCULADORA --------
# 1. Suma
# 2. Resta
# 3. Producto
# 4. División
# 5. Potencia
# 6. Salir
# Seleccione una opción: 6
# SALIENDO...
