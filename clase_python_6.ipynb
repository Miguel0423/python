# %% [markdown]
# ## Programacion Orientada a Objetos
# # Temario
#
# - 1.- Que es POO?
#
# - 2.- Entidades: Clases y Objetos
#
# - 3.- self, init y el ciclo de vida de un objeto
#
# - 4.- Atributos: De instancia vs de clase
#
# - 5.- Metodo: instsancia, clase
#
# - 6.- Encapsulamiento y propiedades
#
# - 7.- Herencia y Abstraccion
#
# - 8.- Polimorfismo
#
# - 9.- Composicion vs Herencia

# %% [markdown]
# ## 1.- Que es POO y por que usarla?
# - Clases (Los Molde)
# Una clase es como el molde o plano para crear algo
#
# - Objetos (Las Creaciones)
# Un objeto es una instancia real tangible creada a partir de una clase.

# %% [markdown]
# ## 2.- Entidades: Clases y Objetos

# %%
class Perro: # SE crea una clase
  def ladrar(self): # Metodo una accion o algo que puede hacer
    print("Guau")
mi_perro = Perro() # Creacion de el Objeto
mi_perro.ladrar() # Acceder al metodo del objeto
# Out:
# Guau

# %% [markdown]
# ## 3.- self, __ init __ y el ciclo de vida de un objeto

# %%
class Perro:
# self es la referencia a la isntancia actial, __ init __
    def __init__(self, nombre, edad):  #Constructor
        self.nombre = nombre
        self.edad = edad
    def presentarse(self):
        print(f"Soy {self.nombre} y tengo {self.edad} años")
pet = Perro("Tobi", 2)
pet.presentarse()
# Out:
# Soy Tobi y tengo 2 años

# %% [markdown]
# ## 4.- Atributos: de instancia vs de clase

# %%
class Perro:
    patas = 4
    especie = "Caninis Familiaris" #Atributos de clase
    def __init__(self,nombre):
        self.nombre = nombre #Atributos de instancia
p1 = Perro("Firulais")
p2 = Perro("Bobby")

print(p1.especie)
print(p2.especie)
print("-------------")
p2.especie = "Gato"
print(p1.especie)
print(p2.especie) #cambio el atributo de la clase ESPECIALMENTE para p2
# Out:
# Caninis Familiaris
# Caninis Familiaris
# -------------
# Caninis Familiaris
# Gato

# %%
print(p1.__dict__)
print(p2.__dict__)
# Out:
# {'nombre': 'Firulais'}
# {'nombre': 'Bobby', 'especie': 'Gato'}

# %% [markdown]
# ##Metodos: De instancia, clase
# Un metodo de instancia es una funcion definida dentro de una clase que:
#
# - Opera sobre un objeto concreto(una instancia)
# - Puede acceder y modificar los atributos de ese objeto
# - Recibe como primer parametro a self

# %%
# (ya lo hemos usado)
class tuClase:
    def metodo(self):
        pass

#metodo -> método de instancia
#self -> referencia al objeto que llama al método

# %%
# Calculadora:
class Calculadora:
    def __init__(self,num1,num2):
        self.num1 = num1
        self.num2 = num2
    def sumar(self):
        print(self.num1 + self.num2)
    def resta(self):
        print(self.num1 - self.num2)
    def multiplicar(self):
        print(self.num1 * self.num2)
    def dividir(self):
        if self.num2 == 0:
            print("Numero no divisible")
        else:
            print(self.num1/self.num2)
Calculadora = Calculadora(7,3)
Calculadora.dividir()
Calculadora.sumar()
Calculadora.multiplicar()
# Out:
# 2.3333333333333335
# 10
# 21

# %%
# EJERCICIO, CREAR UNA CLASE ANIMAL, donde tenga una instancia (Constructor) de por lo menos 3 variables con 1 Metodo y Crea 4 Objetos
class Animal: #1.- Clase
    def __init__(self, nombre, especie, patas, comida_favorita, sonido): #2.- Instancia
        self.nombre = nombre #3.- Variables
        self.especie = especie
        self.patas = patas
        self.comida_favorita = comida_favorita
        self.sonido = sonido

    def hacer_sonido(self): #4.- Metodo
        print(self.sonido)

gato = Animal("Rayitas", "Gato", 4, "Carne de Res", "miau") #4 Objetos
perro = Animal("Mechas", "Perro", 4, "Pollito Asado", "woof")
pajaro = Animal("Paco", "Perico", 2, "Semillas", "pipipi")
vaca = Animal("Manchas", "Vaca", 4, "Pasto", "muuu")

gato.hacer_sonido()
gato.nombre = "Juan"
gato.nombre
# Out:
# miau
# 'Juan'

# %% [markdown]
# ## 6.- Encapsulamiento y propiedades

# %%
class Cuenta:
    def __init__(self,saldo):
        self.__saldo = saldo # Privada
# Sirve para proteger los datos internos de un objeto y controlar como se leen o modifican.
cuenta = Cuenta(1000)
cuenta.Cuenta = 2000 #si puedes editarlo
#print(cuenta.__saldo) # Error: no se puede acceder directamente

# %%
# Getters y Setters
class Cuenta:
    def __init__(self,saldo):
        self.__saldo = saldo
    @property
    def saldo(self): #Getter
        #Permite leer el valor de __saldo usando c.saldo
        return self.__saldo
    @saldo.setter #Setter
    def saldo(self, valor):
        # se ejecuta cuando hacemos c.saldo = valor
        self.__saldo = valor
c = Cuenta(300)
print(c.saldo)
c.saldo = 4000
# Out:
# 300

# %% [markdown]
# ## 7.- Herencia y Abstraccion

# %%
# Herencia
class Vehiculo: #Clase Base (Padre)
    def __init__(self, marca, modelo):
        self.marca = marca
        self.modelo = modelo
    def descipcion(self):
        return f"{self.marca}:{self.modelo}"
    def mover(self):
        return "El vehiculo se esta moviendo..."
#--------------------------------------------------------------------
class Coche(Vehiculo): #subclase 1 (Clase hija)
    def mover(self):
        return "El coche esta conduciendo"
#---------------------------------------------------------------
class Moto(Vehiculo):
    def mover(self):
        return "La moto avanza sobre dos ruedas"

coche = Coche("Toyota", "Corolla")
coche2 = Vehiculo("BYD", "Dolphin")
moto = Moto("Yamaha", "R6")
print(coche.mover())
print(coche2.mover())
print(moto.mover())
#aun que no volvimos a declarar el metodo dentro de descripcion, podemos seguir usandolo ya que lo heredo del padreprint(coche.mover())print(moto.descripcion())print(moto.mover())
# Out:
# El coche esta conduciendo
# El vehiculo se esta moviendo...
# La moto avanza sobre dos ruedas

# %%
class Persona:
    def __init__ (self,nombre, edad):
        self.nombre = nombre
        self.edad = edad
    def presentarse(self):
        print(f"Hola, soy {self.nombre} y tengo {self.edad} anios")

class Estudiante(Persona):
    def __init__(self,nombre, edad, carrera):
        super().__init__(nombre, edad)
        self.carrera = carrera
    def presentarse(self):
        super().presentarse()
        #print(f"Hola, soy {self.nombre} y tengo {self.edad} anios")
        print(f"Estudio la carrera de {self.carrera}")
# Reutiliza el constructor de la clase padre (lo cual evita duplicar el codigo)
# Ejecuta el comportamiento base y luego lo exitiende
est = Estudiante("Ana", 21, "Programacion")
est.presentarse()
# Out:
# Hola, soy Ana y tengo 21 anios
# Estudio la carrera de Programacion

# %%
#Abstraccion
class Animal:
    def hablar(self):
        raise NotImplementedError
class Gato(Animal):
    def hablar(self):
        return "miau"

# %% [markdown]
# ## Polimorfismo
# (Justo ya lo implementamos). El polimorfismo significa que diferentes objetos pueden responder al mismo mensaje(metodo) de forma distinta, siempre y ciando compartan una interfaz comun.

# %% [markdown]
# ## Compiscion HAS-A
# Por que se llama composicion? Porque estas componiendo (armando) un objeto grande usando otros objetos. Es un principio de POO donde:
#
# - Una clase NO hereda de otra, si no que contiene un objeto de esa otra clase

# %%
class Banco:
    def __init__(self,dinero):
        self.dinero = dinero
    def ver_total(self):
        print(f"Total en la cuenta: ${self.dinero}")
class Persona:
    def __init__(self, cuenta: Banco): #Indica que este parametro deberia ser una instancia de la clase Banco
        self.cuenta = cuenta # Persona TIENE un banco, no hereda de el

# %% [markdown]
# ## 9.- Composicion vs Herencia
# Esto se va a responder con pura: No significa que alguna sea mejor que otra simplemente que aveces una te puede convenir mas que otra:
#
# Herencia: un gato ES un animal (no "Un gato TIENE un aniamal") Composicion: Una persona TIENE una cuenta (no "Una persona Es un Banco")
